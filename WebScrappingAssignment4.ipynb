# %% [markdown]
# # Name : Asad ullah
# # Batch : DS2312
# # Web Scraping Assignment-4

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
import requests
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome('/Users/mac/Downloads/chromedriver-mac-x64/chromedriver')

# %%
driver.get(" https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %% [markdown]
# # **Question1**
#
# Scrape the details of most viewed videos on YouTube from Wikipedia. Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)
# Rank
# B) Name
# C) Artist
# D) Upload date E) Views

# %%
tables=[]
table=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[3]/main/div[3]/div[3]/div[1]/table[2]/tbody')
for tr in table.find_elements(By.XPATH,'//tr'):
    row=[item.text for item in tr.find_elements(By.XPATH,'.//td')]
    tables.append(row)
df=pd.DataFrame(tables)

# %%
df=pd.DataFrame(tables)
df=df.drop(columns=[4,5,6,7,8,9])

# %%
df.drop([0],inplace=True) 
df.columns=['Name','Artist','Views','Upload_Date']
df.rename(columns={'0':'Name','1':'Artist','2':'Views','3':'Upload_Date'})
df.head(30)
# Out:
#                                                Name  \
# 1
# 2
# 3                                              None
# 4                             "Baby Shark Dance"[6]
# 5                                    "Despacito"[9]
# 6                        "Johny Johny Yes Papa"[17]
# 7                                   "Bath Song"[18]
# 8                                "Shape of You"[19]
# 9                               "See You Again"[22]
# 10                          "Wheels on the Bus"[27]
# 11                "Phonics Song with Two Words"[28]
# 12                                "Uptown Funk"[29]
# 13  "Learning Colors – Colorful Eggs on a Farm"[30]
# 14                              "Gangnam Style"[31]
# 15   "Masha and the Bear – Recipe for Disaster"[36]
# 16                             "Dame Tu Cosita"[37]
# 17                                     "Axel F"[38]
# 18                                      "Sugar"[39]
# 19                             "Counting Stars"[40]
# ...

# %% [markdown]
# # **Question 2**
#
# Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
# A) Series
# B) Place
# C) Date
# D) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver.get(" https://www.bcci.tv/")

# %%
fixture=driver.find_element(By.XPATH,'//*[@id="imw-international-men"]/a[2]')
fixture.click()

# %%
team= driver.find_element(By.XPATH,'//*[@id="fixtures"]/div[1]/div[2]/div/div[1]/div/div[1]')
team.click()

# %%
search=driver.find_element(By.XPATH,'//input[@class="ng-pristine ng-valid ng-empty ng-touched"]')
search.send_keys('India')

# %%
Series=[]
place=[]
date=[]
time=[]

# %%
series_tags= driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')

for i in range(6):
    s=series_tags[i].text
    Series.append(s)

Series
# Out:
# ['ENGLAND TOUR OF INDIA 2023-24',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024']

# %%
place_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')

for i in place_tags:
    p=i.text
    place.append(p)
place
# Out:
# ['Himachal Pradesh Cricket Association Stadium,',
#  'Harare Sports Club,',
#  'Harare Sports Club,',
#  'Harare Sports Club,',
#  'Harare Sports Club,',
#  'Harare Sports Club,']

# %%
date_tags= driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')

for i in date_tags:
    d=i.text
    date.append(d)
    
date
# Out:
# ['7 MARCH, 2024',
#  '6 JULY, 2024',
#  '7 JULY, 2024',
#  '10 JULY, 2024',
#  '13 JULY, 2024',
#  '14 JULY, 2024']

# %%
time_tags= driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')


for i in time_tags:
    t= i.text
    time.append(t)
    
time
# Out:
# ['4:00 AM GMT',
#  '3:30 PM GMT',
#  '3:30 PM GMT',
#  '3:30 PM GMT',
#  '3:30 PM GMT',
#  '3:30 PM GMT']

# %%
df= pd.DataFrame({'Series': Series, 'Place': place, 'Date': date, 'Time': time})
df
# Out:
#                           Series  \
# 0  ENGLAND TOUR OF INDIA 2023-24
# 1    INDIA TOUR OF ZIMBABWE 2024
# 2    INDIA TOUR OF ZIMBABWE 2024
# 3    INDIA TOUR OF ZIMBABWE 2024
# 4    INDIA TOUR OF ZIMBABWE 2024
# 5    INDIA TOUR OF ZIMBABWE 2024
#
#                                            Place           Date         Time
# 0  Himachal Pradesh Cricket Association Stadium,  7 MARCH, 2024  4:00 AM GMT
# 1                            Harare Sports Club,   6 JULY, 2024  3:30 PM GMT
# 2                            Harare Sports Club,   7 JULY, 2024  3:30 PM GMT
# 3                            Harare Sports Club,  10 JULY, 2024  3:30 PM GMT
# 4                            Harare Sports Club,  13 JULY, 2024  3:30 PM GMT
# 5                            Harare Sports Club,  14 JULY, 2024  3:30 PM GMT

# %% [markdown]
# # **Question 3**
#
# Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details: A) Rank
# B) State
# C) GSDP(18-19)- at current prices D) GSDP(19-20)- at current prices E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver.get("http://statisticstimes.com/")

# %%
economy= driver.find_element(By.XPATH,'//div[@id="top"]/div[2]/div[2]/button')
economy.click()

# %%
India= driver.find_element(By.XPATH,'//div[@class="navbar"]/div[2]/div/a[3]')
India.click()

# %%
StateWiseEco= driver.find_element(By.XPATH,'html/body/div[2]/div[2]/div[2]/ul/li/a')
StateWiseEco.click()

# %%
tables1=[]
table=driver.find_element(By.XPATH,'//div[@id="table_id_wrapper"]/table/tbody')
for tr in table.find_elements(By.XPATH,'//tr'):
    row=[item.text for item in tr.find_elements(By.XPATH,'.//td')]
    tables1.append(row)
df=pd.DataFrame(tables1)
df
# Out:
#          0                                                  1           2  \
# 0   Source  Ministry of Statistics and Programme Implement...        None
# 1     Date                                        21 Dec 2023        None
# 2     None                                               None        None
# 3     None                                               None        None
# 4        1                                        Maharashtra           -
# ..     ...                                                ...         ...
# 69      30                                             Sikkim      35,670
# 70      31                                           Nagaland           -
# 71      32                                            Mizoram           -
# 72      33                          Andaman & Nicobar Islands           -
# 73                                                      India  23,823,945
#
#              3       4           5           6          7
# ...

# %%
df.drop([0,1,2,3,4,5,6,7],inplace=True)
df
# Out:
#      0                          1           2           3      4           5  \
# 8    5                    Gujarat           -   1,937,066  8.25%     259.996
# 9    6                West Bengal   1,554,992   1,363,926  5.81%     183.068
# 10   7                  Rajasthan   1,413,620   1,218,193  5.19%     163.507
# 11   8             Madhya Pradesh   1,322,821   1,136,137  4.84%     152.494
# 12   9             Andhra Pradesh   1,317,728   1,133,837  4.83%     152.185
# ..  ..                        ...         ...         ...    ...         ...
# 69  30                     Sikkim      35,670      31,519  0.16%      17,832
# 70  31                   Nagaland           -      27,859  0.14%           -
# 71  32                    Mizoram           -      24,293  0.12%           -
# 72  33  Andaman & Nicobar Islands           -       9,209  0.05%           -
# 73                          India  23,823,945  20,326,803         13,604,058
#
#              6          7
# ...

# %%
df
# Out:
#      0                          1           2           3      4           5
# 8    5                    Gujarat           -   1,937,066  8.25%     259.996
# 9    6                West Bengal   1,554,992   1,363,926  5.81%     183.068
# 10   7                  Rajasthan   1,413,620   1,218,193  5.19%     163.507
# 11   8             Madhya Pradesh   1,322,821   1,136,137  4.84%     152.494
# 12   9             Andhra Pradesh   1,317,728   1,133,837  4.83%     152.185
# ..  ..                        ...         ...         ...    ...         ...
# 69  30                     Sikkim      35,670      31,519  0.16%      17,832
# 70  31                   Nagaland           -      27,859  0.14%           -
# 71  32                    Mizoram           -      24,293  0.12%           -
# 72  33  Andaman & Nicobar Islands           -       9,209  0.05%           -
# 73                          India  23,823,945  20,326,803         13,604,058
#
# [66 rows x 6 columns]

# %%
df.columns=['Rank','State','GSDP(18-19)- at current prices','GSDP(19-20)- at current prices','Share(18-19)','GDP($ billion)']
df.rename(columns={'0':'Rank','1':'State','2':'GSDP(18-19)- at current prices','3':'GSDP(19-20)- at current prices','4':'Share(18-19)','5':'GDP($ billion)'})
df.head()
# Out:
#    Rank           State GSDP(18-19)- at current prices  \
# 8     5         Gujarat                              -
# 9     6     West Bengal                      1,554,992
# 10    7       Rajasthan                      1,413,620
# 11    8  Madhya Pradesh                      1,322,821
# 12    9  Andhra Pradesh                      1,317,728
#
#    GSDP(19-20)- at current prices Share(18-19) GDP($ billion)
# 8                       1,937,066        8.25%        259.996
# 9                       1,363,926        5.81%        183.068
# 10                      1,218,193        5.19%        163.507
# 11                      1,136,137        4.84%        152.494
# 12                      1,133,837        4.83%        152.185

# %% [markdown]
# # Question 4
# Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description C) Contributors count
# D) Language used

# %%
driver.get('https://github.com/ ')

# %%
menu=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
menu.click()

# %%
trending=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')

# %%
repository_title=[]
title_tags=driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')[0:19]
for i in title_tags:
    repository_title.append(i.text)


repository_title
# Out:
# ['layerdiffusion / sd-forge-layerdiffusion',
#  'naver / dust3r',
#  'EbookFoundation / free-programming-books',
#  'cooderl / wewe-rss',
#  'ReVanced / revanced-manager',
#  'AUTOMATIC1111 / stable-diffusion-webui',
#  'pydantic / FastUI',
#  'iptv-org / iptv',
#  'ente-io / ente',
#  'vercel / ai',
#  'bigcode-project / starcoder2',
#  'adrianhajdin / brainwave',
#  'microsoft / generative-ai-for-beginners',
#  'microsoft / Security-101',
#  'nodejs / nodejs.org',
#  'Lissy93 / web-check',
#  'jafioti / luminal',
#  'cloudcommunity / Free-Certifications',
#  'allenai / OLMo']

# %%
description=[]
contributors=[]
language_used=[]

des=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')[0:19]
for i in des:
    description.append(i.text)
    
cont=driver.find_elements(By.XPATH,'//a[@class="Link Link--muted d-inline-block mr-3"]')[0:19]
for i in cont:
    contributors.append(i.text)
    
language_tags=driver.find_elements(By.XPATH,'//span[@itemprop="programmingLanguage"]')[0:19]
for i in language_tags:
    language_used.append(i.text)

# %%
df=pd.DataFrame({'title':repository_title,'description':description,'No of contributor':contributors,'language':language_used})
df
# Out:
#                                        title  \
# 0   layerdiffusion / sd-forge-layerdiffusion
# 1                             naver / dust3r
# 2   EbookFoundation / free-programming-books
# 3                         cooderl / wewe-rss
# 4                ReVanced / revanced-manager
# 5     AUTOMATIC1111 / stable-diffusion-webui
# 6                          pydantic / FastUI
# 7                            iptv-org / iptv
# 8                             ente-io / ente
# 9                                vercel / ai
# 10              bigcode-project / starcoder2
# 11                  adrianhajdin / brainwave
# 12   microsoft / generative-ai-for-beginners
# 13                  microsoft / Security-101
# 14                       nodejs / nodejs.org
# 15                       Lissy93 / web-check
# 16                         jafioti / luminal
# 17      cloudcommunity / Free-Certifications
# 18                            allenai / OLMo
#
# ...

# %% [markdown]
# # **Question 5**
#
#
# Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the
# following details: A) Song name
# B) Artist name
# C) Last week rank D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver.get("https:/www.billboard.com/")

# %%
top= driver.find_element(By.XPATH,'//div[@class="a-mega-overflow-middle"]/div/div/ul/li/ul/li[2]/a')
top.click()

# %%
song_title=[]
title= driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li/h3')

for i in title:
    song_title.append(i.text)
    
    
len(song_title)
# Out:
# 100

# %%
Artist_name=[]
name= driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li/span')[0:400:4]

for i in name:
    Artist_name.append(i.text)

print(len(Artist_name))
# Out:
# 100

# %%
WeekRank=[]
rank= driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"]')[0:200:2]


for i in rank:
    WeekRank.append(i.text)
    
print(len(WeekRank))
# Out:
# 100

# %%
PeekRank=[]
Prank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-flex-grow-1"]/span')[0:200]

for i in Prank:
    PeekRank.append(i.text)
len(PeekRank)
# Out:
# 100

# %%
WeeksonBoard=[]
onBoard=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"]/span')[1:200:2]

for i in onBoard:
    WeeksonBoard.append(i.text)

    
print(len(WeeksonBoard))
# Out:
# 100

# %%
df=pd.DataFrame({'Song_name':song_title, 'Artist_Name': Artist_name, 'Week_rank':WeekRank,'PeekRank':PeekRank,'WeeksonBoard': WeeksonBoard  })
df
# Out:
#             Song_name                                        Artist_Name  \
# 0      Texas Hold 'Em                                            Beyonce
# 1         Lovin On Me                                        Jack Harlow
# 2        Lose Control                                        Teddy Swims
# 3            Carnival  ¥$: Kanye West & Ty Dolla $ign Featuring Rich ...
# 4    Beautiful Things                                       Benson Boone
# ..                ...                                                ...
# 95            Talking  ¥$: Kanye West & Ty Dolla $ign Featuring North...
# 96             Monaco                                          Bad Bunny
# 97      Where It Ends                                   Bailey Zimmerman
# 98      Wondering Why                                The Red Clay Strays
# 99  Northern Attitude                             Noah Kahan With Hozier
#
#    Week_rank PeekRank WeeksonBoard
# 0          2        1            2
# ...

# %% [markdown]
# # Queston 6
# Scrape the details of Highest selling novels.
# A) Book name B) Author name C) Volumes sold D) Publisher
# E) Genre

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
tables=[]
table=driver.find_element(By.XPATH,'//div[@class="embed block"]/table')
for tr in table.find_elements(By.XPATH,'//tr'):
    row=[item.text for item in tr.find_elements(By.XPATH,'.//td')]
    tables.append(row)
df=pd.DataFrame(tables)
df
# Out:
#                              0  \
# 0                         None
# 1    SOURCE: NIELSEN BOOK SCAN
# 2                            1
# 3                            2
# 4                            3
# ..                         ...
# 97                          96
# 98                          97
# 99                          98
# 100                         99
# 101                        100
#
#                                                      1                 2  \
# 0                                                 None              None
# 1                                                 None              None
# 2                                    Da Vinci Code,The        Brown, Dan
# 3                 Harry Potter and the Deathly Hallows     Rowling, J.K.
# 4             Harry Potter and the Philosopher's Stone     Rowling, J.K.
# ..                                                 ...               ...
# ...

# %%
df.columns=['Rank','Book Name','Author Name','Volume Sold','Publisher','Genre']
df.rename(columns={'0':'Rank','1':'Book Name','2':'Author Name','3':'Volume Sold','4':'Publisher','5':'Genre'})
df.set_index('Rank', inplace=True)
df
# Out:
#                                                                    Book Name  \
# Rank
# None                                                                    None
# SOURCE: NIELSEN BOOK SCAN                                               None
# 1                                                          Da Vinci Code,The
# 2                                       Harry Potter and the Deathly Hallows
# 3                                   Harry Potter and the Philosopher's Stone
# ...                                                                      ...
# 96                                                                 Ghost,The
# 97                                            Happy Days with the Naked Chef
# 98                                     Hunger Games,The:Hunger Games Trilogy
# 99                         Lost Boy,The:A Foster Child's Search for the L...
# 100                        Jamie's Ministry of Food:Anyone Can Learn to C...
#
# ...

# %% [markdown]
# # Question 7
#
# Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have
# to find the following details: A) Name
# B) Year span
# C) Genre
# D) Run time E) Ratings F) Votes

# %%
driver.get('https://www.imdb.com/list/ls512407256/')

# %%
tv_series=[]
series=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')

for i in series:
    tv_series.append(i.text)
    
print(len(tv_series))
# Out:
# 100

# %%
year_span=[]

years= driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')

for i in years:
    year_span.append(i.text)
    
print(len(year_span))
# Out:
# 100

# %%
genre=[]

gen= driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[5]')

for i in gen:
    genre.append(i.text)
    
len(genre)
# Out:
# 100

# %%
run_time=[]

time= driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[3]')

for i in time:
    run_time.append(i.text)
    
len(run_time)
# Out:
# 100

# %%
rating=[]

rat= driver.find_elements(By.XPATH,'//div[@class="ipl-rating-widget"]/div/span[2]')

for i in rat:
    rating.append(i.text)

# %%
vote=[]

vo= driver.find_elements(By.XPATH,'//span[@name="nv"]')


for i in vo:
    vote.append(i.text)

# %%
df= pd.DataFrame({'Tv_Series':tv_series, 'year_span': year_span, 'genre': genre, 'run_time': run_time, 'rating': rating, 'vote': vote })
df
# Out:
#                Tv_Series    year_span                     genre run_time  \
# 0        Game of Thrones  (2011–2019)  Action, Adventure, Drama   55 min
# 1        Stranger Things  (2016–2025)    Drama, Fantasy, Horror   51 min
# 2       The Walking Dead  (2010–2022)   Drama, Horror, Thriller   44 min
# 3         13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller   60 min
# 4                The 100  (2014–2020)    Drama, Mystery, Sci-Fi   43 min
# ..                   ...          ...                       ...      ...
# 95        True Detective     (2014– )     Crime, Drama, Mystery   55 min
# 96             Teen Wolf  (2011–2017)    Action, Drama, Fantasy   41 min
# 97                The OA  (2016–2019)   Drama, Fantasy, Mystery   60 min
# 98          The Simpsons     (1989– )         Animation, Comedy   22 min
# 99  Desperate Housewives  (2004–2012)    Comedy, Drama, Mystery   45 min
#
#    rating       vote
# 0     9.2  2,263,160
# 1     8.7  1,320,899
# 2     8.1  1,072,613
# ...

# %% [markdown]
# # Question 8
# Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/ You
# have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver.get('https://archive.ics.uci.edu/ ')

# %%
dataset=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[1]/div/div/div/a[1]')
dataset.click()

# %%
Task=[]
year=[]

# %%
Dataset_name=[]
Data_type=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]

# %%
import time
start=0
end=65
for page in range(start,end):
    name_tags=driver.find_elements(By.XPATH,'//a[@class="link-hover link text-xl font-semibold"]')[:500]
    for i in name_tags:
        Dataset_name.append(i.text)
        
    data_type=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]/span')[0:550:4]
    for i in data_type:
        Data_type.append(i.text)
        
    attributetype_tags=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]/span')[1:550:4]
    for i in attributetype_tags:
        Attribute_type.append(i.text)
        
    instance_tags=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]/span')[2:550:4]
    for i in instance_tags:
        No_of_instances.append(i.text)
        
    attribute_tags=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]/span')[3:550:4]
    for i in attribute_tags:
        No_of_attribute.append(i.text)
        
    next_button=driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_button.click()
    time.sleep(2)

# %%
print(len(Dataset_name),len(Data_type),len(Attribute_type),len(No_of_instances),len(No_of_attribute))
# Out:
# 650 619 609 590 569

# %%
df1=pd.DataFrame(Dataset_name)[:500]
df2=pd.DataFrame(Data_type)[:500]
df3=pd.DataFrame(Attribute_type)[:500]
df4=pd.DataFrame(No_of_instances)[:500]
df5=pd.DataFrame(No_of_attribute)[:500]

# %%
result = pd.concat([df1,df2,df3,df4,df5], axis=1)
result
# Out:
#                                                      0 0  0  0  0
# 0                                                 Iris
# 1                                     Dry Bean Dataset
# 2                                        Heart Disease
# 3                           Rice (Cammeo and Osmancik)
# 4                                                Adult
# ..                                                 ... .. .. .. ..
# 495  Online Video Characteristics and Transcoding T...
# 496  UrbanGB, urban road accidents coordinates labe...
# 497                     Guitar Chords finger positions
# 498                                  Refractive errors
# 499                                        Hill-Valley
#
# [500 rows x 5 columns]
