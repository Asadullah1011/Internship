# %% [markdown]
# #  Name : Asad ullah
# # Batch : DS2312

# %% [markdown]
# **HR Analytics Project- Understanding the Attrition in HR**
#
#
#
# **Project Description**
#
#
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
#
#
# HR Analytics
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
#
# Attrition in HR
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
#
# Attrition affecting Companies
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head(15)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Checking shape of Dataset

df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Checking the columns of dataset
df.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# No null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Let's visulize using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Checking the values of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64
#
#
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
#
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
#
# DailyRate
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: count, Length: 886, dtype: int64
#
#
# Department
# Research & Development    961
# Sales                     446
# ...

# %% [markdown]
# There is no spaces in categorical columns and no null values in data set

# %%
df= df.drop('EmployeeNumber', axis=True)
df= df.drop('EmployeeCount', axis=True)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# **Separating categorical and Numerical columns**

# %%
#Checking for categorical columns
categorical_col= []
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns: ", categorical_col)
print("\n")


#Checking for Numerical columns
numerical_col= []
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Columns: ", numerical_col)
print("\n")
# Out:
# Categorical Columns:  ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
#
#
# Numerical Columns:  ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
#Checking number of unique values in each column
df.nunique().to_frame("No of unique Values")
# Out:
#                           No of unique Values
# Age                                        43
# Attrition                                   2
# BusinessTravel                              3
# DailyRate                                 886
# Department                                  3
# DistanceFromHome                           29
# Education                                   5
# EducationField                              6
# EnvironmentSatisfaction                     4
# Gender                                      2
# HourlyRate                                 71
# JobInvolvement                              4
# JobLevel                                    5
# JobRole                                     9
# JobSatisfaction                             4
# MaritalStatus                               3
# MonthlyIncome                            1349
# MonthlyRate                              1427
# NumCompaniesWorked                         10
# ...

# %%
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#Our classification problem in binary classification beacuse two possible outcome either yes or no

df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %% [markdown]
# Dataset looks imbalance deal with it later

# %% [markdown]
# **Description of DataSet**

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# There are outliers in dataset

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# **Univariate Analysis**

# %%
ax= sns.countplot(x='Attrition', data=df)
print(df['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='BusinessTravel', data=df)
print(df['BusinessTravel'].value_counts())
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='Department', data=df)
print(df['Department'].value_counts())
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='EducationField', data=df)
print(df['EducationField'].value_counts())
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='Gender', data=df)
print(df['Gender'].value_counts())
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='Gender', data=df)
print(df['Gender'].value_counts())
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='JobRole', data=df)
print(df['JobRole'].value_counts())
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='MaritalStatus', data=df)
print(df['MaritalStatus'].value_counts())
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
ax= sns.countplot(x='OverTime', data=df)
print(df['OverTime'].value_counts())
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %% [markdown]
# **BiVaraite Analysis**

# %%
#Comparing Age and Gender
plt.title("Comparison between Age and SeniorCitizen")
sns.stripplot(x= 'Age', y='Gender', data=df)
plt.show()

# %%
plt.title("Comparison between Job Satisfaction and Monthly Income")
sns.stripplot(x= 'JobSatisfaction', y='MonthlyIncome', data=df, hue='Attrition', palette= 'bright')
plt.show()

# %% [markdown]
# Attrition more when Monthly income low as monthly income increase attrition become less

# %%
sns.catplot(x='Attrition', col='Gender', data=df, kind='count')

sns.catplot(x='Attrition', col='BusinessTravel', data=df, kind='count')

sns.catplot(x='Attrition', col='Department', data=df, kind='count')


sns.catplot(x='Attrition', col='EducationField', data=df, kind='count')

sns.catplot(x='Attrition', col='JobRole', data=df, kind='count')

sns.catplot(x='Attrition', col='Over18', data=df, kind='count')

sns.catplot(x='Attrition', col='OverTime', data=df, kind='count')

# %%
sns.stripplot(x= 'Age', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'DailyRate', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'DistanceFromHome', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'Education', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'EnvironmentSatisfaction', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'HourlyRate', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'TotalWorkingYears', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'TrainingTimesLastYear', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'WorkLifeBalance', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'YearsAtCompany', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'YearsInCurrentRole', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'YearsSinceLastPromotion', y='Attrition', data=df, palette= 'bright')
plt.show()

# %%
sns.stripplot(x= 'YearsWithCurrManager', y='Attrition', data=df, palette= 'bright')
plt.show()

# %% [markdown]
# # Multi Variate Analysis

# %%
#sns.pairplot(df,hue='Attrition', palette='Dark2')
#plt.show()

# %%
#Let's check how data has been distributed in remaining columns
plt.figure(figsize=(10,6), facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=9:
        ax= plt.subplot(2,5, plotnumber)
        sns.distplot(df[col], color='m')
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation=0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# No Skewness in data

# %% [markdown]
# # Checking for Outliers

# %%
plt.figure(figsize=(10,6), facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=9:
        ax= plt.subplot(2,5, plotnumber)
        sns.boxplot(df[col], palette= "Set2_r")
        plt.xlabel(col, fontsize=15)
        plt.yticks(rotation=0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# No Outliers in data

# %% [markdown]
# # Encoding Categorical Columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE= OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]= OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   float64
#  2   BusinessTravel            1470 non-null   float64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   float64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   float64
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   float64
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1470.000000  1470.000000     1470.000000              1470.000000
# mean           9.192517     2.912925        2.247619                 2.721769
# ...

# %% [markdown]
# **Corelation between label and features**

# %%
cor= df.corr()
cor
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# JobInvolvement            0.029820  -0.130016        0.039062   0.046135
# ...

# %% [markdown]
# **Visualize corelation by heatmap**

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor='black', annot=True, cmap= "Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
#Drop Over18 and StandardHours because they are not corelate

df= df.drop('Over18', axis=1)   
df= df.drop('StandardHours', axis=1)
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor='black', annot=True, cmap= "Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
plt.figure(figsize=(22,7))
df.corr()['Attrition'].sort_values(ascending=False).drop(['Attrition']).plot(kind='bar', color='m')
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title("Corelation between label and feature using barplot", fontsize=20)
plt.show()

# %%
cor['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# OverTime                    0.246118
# MaritalStatus               0.162070
# DistanceFromHome            0.077924
# JobRole                     0.067151
# Department                  0.063991
# NumCompaniesWorked          0.043494
# Gender                      0.029453
# EducationField              0.026846
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# BusinessTravel              0.000074
# HourlyRate                 -0.006846
# PercentSalaryHike          -0.013478
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# ...

# %% [markdown]
# **Separating label and Features**

# %%
x= df.drop("Attrition", axis=1)
y= df["Attrition"]

# %% [markdown]
# Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns= x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.446350        0.590048   0.742527    1.401512         -1.010909
# 1     1.322365       -0.913194  -1.297775   -0.493817         -0.147150
# 2     0.008343        0.590048   1.414363   -0.493817         -0.887515
# 3    -0.429664       -0.913194   1.461466   -0.493817         -0.764121
# 4    -1.086676        0.590048  -0.524295   -0.493817         -0.887515
# ...        ...             ...        ...         ...               ...
# 1465 -0.101159       -0.913194   0.202082   -0.493817          1.703764
# 1466  0.227347        0.590048  -0.469754   -0.493817         -0.393938
# 1467 -1.086676        0.590048  -1.605183   -0.493817         -0.640727
# 1468  1.322365       -0.913194   0.546677    1.401512         -0.887515
# 1469 -0.320163        0.590048  -0.432568   -0.493817         -0.147150
#
#       Education  EducationField  EnvironmentSatisfaction    Gender  \
# ...

# %% [markdown]
# **Checking Variance Inflation**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values                  Features
# 0     2.054172                       Age
# 1     1.016413            BusinessTravel
# 2     1.023990                 DailyRate
# 3     1.942150                Department
# 4     1.017135          DistanceFromHome
# 5     1.063531                 Education
# 6     1.016236            EducationField
# 7     1.017516   EnvironmentSatisfaction
# 8     1.019383                    Gender
# 9     1.021142                HourlyRate
# 10    1.020804            JobInvolvement
# 11   11.821396                  JobLevel
# 12    1.894260                   JobRole
# 13    1.020727           JobSatisfaction
# 14    1.840999             MaritalStatus
# 15   11.052627             MonthlyIncome
# 16    1.015602               MonthlyRate
# 17    1.261957        NumCompaniesWorked
# 18         NaN                    Over18
# 19    1.028587                  OverTime
# 20    2.521576         PercentSalaryHike
# 21    2.519366         PerformanceRating
# ...

# %%
x.drop('JobLevel', axis=1,inplace= True)

# %%
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values                  Features
# 0     2.052478                       Age
# 1     1.014918            BusinessTravel
# 2     1.023716                 DailyRate
# 3     1.849155                Department
# 4     1.013448          DistanceFromHome
# 5     1.063510                 Education
# 6     1.015584            EducationField
# 7     1.016863   EnvironmentSatisfaction
# 8     1.019039                    Gender
# 9     1.018639                HourlyRate
# 10    1.020643            JobInvolvement
# 11    1.867017                   JobRole
# 12    1.020480           JobSatisfaction
# 13    1.840999             MaritalStatus
# 14    2.579927             MonthlyIncome
# 15    1.015308               MonthlyRate
# 16    1.261360        NumCompaniesWorked
# 17         NaN                    Over18
# 18    1.028311                  OverTime
# 19    2.520564         PercentSalaryHike
# 20    2.519362         PerformanceRating
# 21    1.020796  RelationshipSatisfaction
# ...

# %%
y.value_counts()
# Out:
# Attrition
# 0.0    1233
# 1.0     237
# Name: count, dtype: int64

# %% [markdown]
# Data is imblance let's deal with it

# %%
from imblearn.over_sampling import SMOTE
SM= SMOTE()
x1,y1= SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# Attrition
# 0.0    1233
# 1.0     237
# Name: count, dtype: int64

# %%
y1.value_counts()
# Out:
# Attrition
# 1.0    1233
# 0.0    1233
# Name: count, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

maxAccu=0
maxRS=0

for i in range(1,200):
    x_train, x_test, y_train, y_test= train_test_split(x1,y1, test_size=0.30, random_state=i)
    RFR= RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred= RFR.predict(x_test)
    acc= accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu= acc
        maxRS=i
print("Best Accuracy is ", maxAccu,"at random state", maxRS)
# Out:
# Best Accuracy is  0.9594594594594594 at random state 39

# %%
 x_train, x_test, y_train, y_test= train_test_split(x1,y1, test_size=0.30, random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# **Logistic Regression**

# %%
LR= LogisticRegression()
LR.fit(x_train, y_train)
predLR= LR.predict(x_test)
print(accuracy_score(y_test, predLR))
print(confusion_matrix(y_test, predLR))
print(classification_report(y_test, predLR))
# Out:
# 0.7918918918918919
# [[302  85]
#  [ 69 284]]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.78      0.80       387
#          1.0       0.77      0.80      0.79       353
#
#     accuracy                           0.79       740
#    macro avg       0.79      0.79      0.79       740
# weighted avg       0.79      0.79      0.79       740

# %% [markdown]
# **Random Forest Classifier**

# %%
RF= RandomForestClassifier()
RF.fit(x_train, y_train)
predRF= RF.predict(x_test)
print(accuracy_score(y_test, predRF))
print(confusion_matrix(y_test, predRF))
print(classification_report(y_test, predRF))
# Out:
# 0.9567567567567568
# [[376  11]
#  [ 21 332]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96       387
#          1.0       0.97      0.94      0.95       353
#
#     accuracy                           0.96       740
#    macro avg       0.96      0.96      0.96       740
# weighted avg       0.96      0.96      0.96       740

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
GB= GradientBoostingClassifier()
GB.fit(x_train, y_train)
predGB= GB.predict(x_test)
print(accuracy_score(y_test, predGB))
print(confusion_matrix(y_test, predGB))
print(classification_report(y_test, predGB))
# Out:
# 0.9364864864864865
# [[371  16]
#  [ 31 322]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.96      0.94       387
#          1.0       0.95      0.91      0.93       353
#
#     accuracy                           0.94       740
#    macro avg       0.94      0.94      0.94       740
# weighted avg       0.94      0.94      0.94       740

# %% [markdown]
# **Ada Boost**

# %%
AB= AdaBoostClassifier()
AB.fit(x_train, y_train)
predAB= AB.predict(x_test)
print(accuracy_score(y_test, predAB))
print(confusion_matrix(y_test, predAB))
print(classification_report(y_test, predAB))
# Out:
# 0.9135135135135135
# [[353  34]
#  [ 30 323]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.91      0.92       387
#          1.0       0.90      0.92      0.91       353
#
#     accuracy                           0.91       740
#    macro avg       0.91      0.91      0.91       740
# weighted avg       0.91      0.91      0.91       740

# %% [markdown]
# **Extra Tree Clasifier**

# %%
ET= ExtraTreesClassifier()
ET.fit(x_train, y_train)
predET= ET.predict(x_test)
print(accuracy_score(y_test, predET))
print(confusion_matrix(y_test, predET))
print(classification_report(y_test, predET))
# Out:
# 0.9662162162162162
# [[369  18]
#  [  7 346]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.95      0.97       387
#          1.0       0.95      0.98      0.97       353
#
#     accuracy                           0.97       740
#    macro avg       0.97      0.97      0.97       740
# weighted avg       0.97      0.97      0.97       740

# %% [markdown]
# **Cross Validation**

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking for cross validation score for Random Forest
score= cross_val_score(RF, x,y)
print(score)
print(score.mean)
print('Difference between Accuracy score and Cross validation score', accuracy_score(y_test, predRF)-score.mean())
# Out:
# [0.8537415  0.86394558 0.85714286 0.86054422 0.86054422]
# <built-in method mean of numpy.ndarray object at 0x1342b1e90>
# Difference between Accuracy score and Cross validation score 0.09757308328736913

# %%
#Checking for cross validation score for Logistic Regression
score= cross_val_score(LR, x,y)
print(score)
print(score.mean)
print('Difference between Accuracy score and Cross validation score', accuracy_score(y_test, predLR)-score.mean())
# Out:
# [0.88095238 0.86394558 0.86734694 0.85034014 0.8707483 ]
# <built-in method mean of numpy.ndarray object at 0x13687ff30>
# Difference between Accuracy score and Cross validation score -0.07477477477477468

# %%
#Checking for cross validation score for Gradient Boosting
score= cross_val_score(GB, x,y)
print(score)
print(score.mean)
print('Difference between Accuracy score and Cross validation score', accuracy_score(y_test, predGB)-score.mean())
# Out:
# [0.85034014 0.87414966 0.8707483  0.86394558 0.87755102]
# <built-in method mean of numpy.ndarray object at 0x134806610>
# Difference between Accuracy score and Cross validation score 0.0691395477109763

# %%
#Checking for cross validation score for Ada Boost
score= cross_val_score(AB, x,y)
print(score)
print(score.mean)
print('Difference between Accuracy score and Cross validation score', accuracy_score(y_test, predAB)-score.mean())
# Out:
# [0.85714286 0.86734694 0.8877551  0.85714286 0.89455782]
# <built-in method mean of numpy.ndarray object at 0x13687ff30>
# Difference between Accuracy score and Cross validation score 0.0407243978672549

# %% [markdown]
# Random Forest Classifier gave best result

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

parameters= {'criterion':['gini', 'entropy'],
              'random_state':[10,50,1000],
             'max_depth':[0, 10, 20],
            'n_jobs':[-2,-1,1],
            'n_estimators':[50,100,200]}

# %%
GCV= GridSearchCV(RandomForestClassifier(),parameters, cv=5)

# %%
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200], 'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'n_estimators': 200,
#  'n_jobs': -2,
#  'random_state': 50}

# %%
# Evaluate the model with the best parameters
Final_model=RandomForestClassifier(criterion='gini', 
             max_depth= 20,
            random_state= 50,
            n_jobs=-2,
            n_estimators=200)
Final_model.fit(x_train, y_train)
pred= Final_model.predict(x_test)
acc= accuracy_score(y_test, pred)
print(acc*100)
# Out:
# 95.27027027027027

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(Final_model, "HR Analytics")
# Out:
# ['HR Analytics']

# %%
import pickle
filename= 'HR Analytics'
pickle.dump(Final_model, open(filename, 'wb'))
